# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta

# %%
# Define OMX Helsinki 25 stock symbols
omxh25_symbols = [
    'NESTE.HE', 'KNEBV.HE', 'FORTUM.HE', 'NDA-FI.HE', 'UPM.HE',
    'STERV.HE', 'MOCORP.HE', 'SAMPO.HE', 'KESKOA.HE', 'NOKIA.HE',
    'WRT1V.HE', 'TELIA1.HE', 'VALMT.HE', 'OUT1V.HE', 'ELISA.HE',
    'HUH1V.HE', 'KCR.HE', 'CGCBV.HE', 'AMEAS.HE', 'YTY1V.HE',
    'FSKRS.HE', 'CAPMAN.HE', 'QTCOM.HE', 'UNR1V.HE', 'KOJAMO.HE'
]

# %%
# Define the end date as today
end_date = datetime.now().strftime('%Y-%m-%d')

# Create an empty dictionary to store stock data for each company
omxh25_data = {}
failed_symbols = []

# %%
# Iterate through symbols and attempt to retrieve data
for symbol in omxh25_symbols:
    try:
        # Attempt to retrieve data with a start date one year ago
        start_date = (datetime.now() - timedelta(days=365)).strftime('%Y-%m-%d')
        stock_data = yf.download(symbol, start=start_date, end=end_date)
        
        # Check if the retrieved DataFrame is not empty
        if not stock_data.empty:
            omxh25_data[symbol] = stock_data
        else:
            print(f"No data found for {symbol}")
            failed_symbols.append(symbol)
    except Exception as e:
        print(f"Failed to download data for {symbol}: {e}")
        failed_symbols.append(symbol)

print("Symbols that failed to download data:", failed_symbols)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MOCORP.HE']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# No data found for MOCORP.HE
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMEAS.HE']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['YTY1V.HE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-02-09 -> 2024-02-09)')
# No data found for AMEAS.HE
# No data found for YTY1V.HE
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['UNR1V.HE']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-02-09 -> 2024-02-09)')
# [*********************100%%**********************]  1 of 1 completed
# No data found for UNR1V.HE
# Symbols that failed to download data: ['MOCORP.HE', 'AMEAS.HE', 'YTY1V.HE', 'UNR1V.HE']

# %%
# Save data for each company to separate Excel files
folder_path = r'C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\'  # Modify this path as needed

for symbol, data in omxh25_data.items():
    file_path = f"{folder_path}{symbol}.xlsx"
    data.to_excel(file_path)
    print(f"Data exported to {file_path} successfully!")
# Out:
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\NESTE.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\KNEBV.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\FORTUM.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\NDA-FI.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\UPM.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\STERV.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\SAMPO.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\KESKOA.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\NOKIA.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\WRT1V.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\TELIA1.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\VALMT.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\OUT1V.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\ELISA.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\HUH1V.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\KCR.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\CGCBV.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\FSKRS.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\CAPMAN.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\QTCOM.HE.xlsx successfully!
# Data exported to C:\Users\Ricks\OneDrive\Skrivbord\Aktie plan\Aktie data\\KOJAMO.HE.xlsx successfully!

# %%
# Symbol for Wärtsilä Corporation
company_symbol = 'NESTE.HE'

# Fetch the stock data for Wärtsilä Corporation
wartsila_data = omxh25_data[company_symbol]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(wartsila_data['Close'], label='Close Price')
plt.title('Stock Price for Wärtsilä Corporation (WRT1V.HE)')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()
